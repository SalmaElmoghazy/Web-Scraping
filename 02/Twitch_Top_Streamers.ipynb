# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import ast

# %%
def clean_num(num_text):
    num_text = num_text.replace(',', '')
    multiplier = 1
    if 'K' in num_text:
        multiplier = 1000
    elif 'M' in num_text:
        multiplier = 1000000
    try:  
        num = ast.literal_eval(re.findall(r'\d+(?:\.\d+)?', num_text)[0]) * multiplier
    except:
        num = num_text
    return num

# %%
clean_num("+1.2K")
# Out:
# 1200.0

# %%
# Set up chrome driver
driver = webdriver.Chrome()
a = int(input("Enter starting page: "))
b = int(input("Enter Ending page: "))
all_details = []
for page_no in range(a, b + 1):
    try:
        # Get current page
        driver.get("https://twitchtracker.com/channels/ranking/french?page={}".format(page_no))
        print("\nPage:\nhttps://twitchtracker.com/channels/ranking/french?page={}".format(page_no))
        records = driver.find_elements(By.TAG_NAME, 'tr')
        
        for record in records:
            
            fields = record.find_elements(By.TAG_NAME,'td')
            if len(fields) < 11:
                continue
            
            extracted_record = {
                'name': '',
                'avg_viewers': '',
                'time_streamed': '',
                'all_time_peak_viewers': '',
                'hours_watched': '',
                'rank': '', 
                'follower_gained': '',
                'total_followers': '',
                'total_views': ''
                
            }
            extracted_record['name'] = fields[2].text
            extracted_record['avg_viewers'] = clean_num(fields[3].text)
            extracted_record['time_streamed'] = clean_num(fields[4].text)
            extracted_record['all_time_peak_viewers'] = clean_num(fields[5].text)
            extracted_record['hours_watched'] = clean_num(fields[6].text)
            extracted_record['rank'] = clean_num(fields[7].text)
            extracted_record['follower_gained'] = clean_num(fields[8].text)
            extracted_record['total_followers'] = clean_num(fields[9].text)
            extracted_record['total_views'] = clean_num(fields[10].text)
            
            # Append record to all details
            all_details.append(extracted_record)
            

    except Exception as e:
        # Close the browser if we run to an error
        print(e)
        driver.close()
# Out:
# Enter starting page: 1
# Enter Ending page: 50
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=1
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=2
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=3
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=4
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=5
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=6
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=7
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=8
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=9
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=10
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=11
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=12
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=13
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=14
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=15
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=16
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=17
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=18
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=19
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=20
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=21
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=22
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=23
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=24
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=25
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=26
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=27
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=28
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=29
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=30
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=31
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=32
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=33
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=34
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=35
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=36
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=37
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=38
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=39
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=40
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=41
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=42
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=43
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=44
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=45
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=46
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=47
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=48
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=49
#
# Page:
# https://twitchtracker.com/channels/ranking/french?page=50

# %%
df = pd.DataFrame(all_details)
df
# Out:
#             name  avg_viewers  time_streamed  all_time_peak_viewers  \
# 0     AMINEMATUE        34459           57.7                1155060
# 1         KAMET0        19279          164.8                 419458
# 2        OTPLOL_         5954          718.8                 204072
# 3       SQUEEZIE        28164           42.3                1340960
# 4         JLTOMY        13935          145.9                 261719
# ...          ...          ...            ...                    ...
# 2373   ALOAKIRBY           42           67.8                    685
# 2374    ZEBLOODY           29          137.6                    491
# 2375     FRENCHI           37           90.4                   2844
# 2376      LANFEY           53           35.2                    649
# 2377    SNAXOLID           44           59.7                    645
#
#       hours_watched   rank  follower_gained total_followers  total_views
# 0         1990000.0     26          19700.0       2760000.0   14900000.0
# 1         3180000.0     28           5500.0       1890000.0    108000000
# 2         4280000.0     31           4300.0          741000  100000000.0
# 3         1190000.0     49          23700.0       5070000.0   66700000.0
# 4         2030000.0     61           9000.0       1270000.0   50300000.0
# ...             ...    ...              ...             ...          ...
# 2373         2900.0  46865             67.0          2800.0           --
# 2374         4000.0  46896             57.0          5000.0           --
# 2375         3300.0  46912             38.0          8000.0           --
# 2376         1900.0  46918            104.0          7300.0           --
# 2377         2700.0  46922             28.0             340           --
#
# [2378 rows x 9 columns]

# %%
# Save the information into a CSV file
df.to_csv("Rankings_Table.csv", sep=',')
